# %%
# %run test.py
# Out:
# 100

# %%
square(108)
# Out:
# 11664

# %%
# %timeit print('Hello AI')
# Out:
# I
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# Hello AI
# ...
